# %%
import os

def add_dot_to_md_files(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.md'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                # Remove any trailing whitespace and add a dot
                content = content.rstrip() + '.'
                
                with open(file_path, 'w', encoding='utf-8') as f:
                    f.write(content)
                print(f"Processed: {file_path}")

# Replace this with the actual path to your tolstoy-toly-kb folder
folder_path = 'C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb'

add_dot_to_md_files(folder_path)
print("Done processing all .md files.")
# Out:
# Processed: C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb\README.md
# Processed: C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb\.git\logs\refs\remotes\origin\create-pdp-stories.md
# Processed: C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb\.git\logs\refs\remotes\origin\update-tolstoy-toly-kb-products-play-introduction-use-cases-examples-of-product-page-stories.md
# Processed: C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb\.git\refs\remotes\origin\create-pdp-stories.md
# Processed: C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb\.git\refs\remotes\origin\update-tolstoy-toly-kb-products-play-introduction-use-cases-examples-of-product-page-stories.md
# Processed: C:/Users/Monkey D. Luffy/Development/Tolstoy/tolstoy-toly-kb\app-and-player\topics\knowledge-manager-articles\getting-started-with-tolstoy-for-content-creation.md
# ...
